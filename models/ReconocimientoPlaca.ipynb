# %% [markdown]
# # Modelo Placa

# %% [markdown]
# ## 1. Cargar Librerías necesarias

# %% [markdown]
# ## ultralytics
# Librería de entrenamiento e inferencia de modelos de Visión por Computadora, principalmente YOLO (You Only Look Once). Es el marco de trabajo líder para arquitecturas YOLO (v8, v5, etc.), permitiendo cargar modelos, entrenar con datos personalizados y realizar predicciones.
#
# ## roboflow
#
# Librería de gestión de datos para Visión por Computadora.
# Facilita la descarga de datasets etiquetados desde la plataforma Roboflow,
# la conversión de formatos de anotación y la preparación de datos para
# el entrenamiento de modelos.

# %%
# !pip install roboflow ultralytics

# %% [markdown]
# ## 2. Descargar el dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="FaKLU09Td4T6ddL848KF")
project = rf.workspace("licenseplate-s6fjf").project("license-plate-xmnzu")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to license-plate-1 in yolov11:: 100%|██████████| 10900/10900 [00:03<00:00, 2790.69it/s]
